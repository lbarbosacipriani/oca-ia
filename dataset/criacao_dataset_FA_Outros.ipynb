# %%
# !pip install wfdb
# Out:
# O kernel falhou ao iniciar porque o ambiente do Python “Python 3.13.13” não está mais disponível. Considere selecionar outro kernel ou atualizar a lista de Ambientes do Python.

# %%
import pandas as pd
df = pd.read_csv('norm_outros_dataset.csv')
# Out:
# A execução de células com 'Python 3.13.13' requer o pacote ipykernel.
#
# Instale 'ipykernel' no ambiente Python.
#
# Comando: '/opt/homebrew/bin/python3.13 -m pip install ipykernel -U --user --force-reinstall'

# %%
df['macro_class'].value_counts()
# Out:
# macro_class
# 0    11586
# 1     9194
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import wfdb
import ast

def load_raw_data(df, sampling_rate, path):
    if sampling_rate == 100:
        data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

path = ''
sampling_rate=100

# load and convert annotation data
Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))



# Load scp_statements.csv for diagnostic aggregation
agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)
agg_df = agg_df[agg_df.diagnostic == 1]
afib_repo = 'AFIB'
def aggregate_diagnostic(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in afib_repo:
            tmp.append('AFIB')
        elif key in norm_repo:
            tmp.append('')
        else:
            tmp.append('Other')
    return list(set(tmp))[-1]

# Apply diagnostic superclass
print(aggregate_diagnostic)
Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)
# Out:
# <function aggregate_diagnostic at 0x1162a4ea0>

# %%
Y['path']=Y['filename_lr'].apply(lambda x: x.split('/')[-1]+'-0.png')

# %%
## generate csv with columns path and diagnostic_superclass
Y[['path', 'diagnostic_superclass']].to_csv('dataset_FA_Outros.csv', index=False)

# %%
Y['path'].to_csv('dataset_FA_Outros.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13167/2823892959.py in <cell line: 0>()
# ----> 1 Y['path'].to_csv('dataset_FA_Outros.csv')
#
# NameError: name 'Y' is not defined
